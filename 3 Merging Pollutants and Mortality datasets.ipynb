# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_excel('/state_tier1_caps_05Apr2023_Ktons.xlsx', sheet_name='State_Trends')

# %%
data.shape
# Out:
# (7136, 33)

# %%
data.columns
# Out:
# Index(['State FIPS', 'State', 'Tier 1 Code', 'Tier 1 Description', 'Pollutant',
#        'emissions1990', 'emissions1996', 'emissions1997', 'emissions1998',
#        'emissions1999', 'emissions2000', 'emissions2001', 'emissions2002',
#        'emissions2003', 'emissions2004', 'emissions2005', 'emissions2006',
#        'emissions2007', 'emissions2008', 'emissions2009', 'emissions2010',
#        'emissions2011', 'emissions2012', 'emissions2013', 'emissions2014',
#        'emissions2015', 'emissions2016', 'emissions2017', 'emissions2018',
#        'emissions2019', 'emissions2020', 'emissions2021', 'emissions2022'],
#       dtype='object')

# %%
data = data[data['Pollutant'] == 'PM10-PRI']

# %%
data.shape
# Out:
# (795, 33)

# %%
data.head()
# Out:
#     State FIPS State  Tier 1 Code             Tier 1 Description Pollutant  \
# 5            1    AL            1         Fuel Comb. Elec. Util.  PM10-PRI
# 14           1    AL            2          Fuel Comb. Industrial  PM10-PRI
# 23           1    AL            3               Fuel Comb. Other  PM10-PRI
# 32           1    AL            4  Chemical & Allied Product Mfg  PM10-PRI
# 41           1    AL            5              Metals Processing  PM10-PRI
#
#     emissions1990  emissions1996  emissions1997  emissions1998  emissions1999  \
# 5         8.85994        9.28102        8.83472        8.37946      29.217020
# 14       12.63573       10.87613       10.53728       10.56054       8.582618
# 23       13.61068        6.01598        6.04569        5.82756       6.142005
# 32        1.01733        1.04790        1.07280        1.10829       1.068639
# 41        5.50261        7.70230        7.94346        7.71736      10.770767
#
# ...

# %%
data.isna().sum()
# Out:
# State FIPS              0
# State                   3
# Tier 1 Code             0
# Tier 1 Description      3
# Pollutant               0
# emissions1990         191
# emissions1996         174
# emissions1997         174
# emissions1998         174
# emissions1999         162
# emissions2000         162
# emissions2001         162
# emissions2002           5
# emissions2003           5
# emissions2004           5
# emissions2005           5
# emissions2006           5
# emissions2007           5
# emissions2008           5
# emissions2009           5
# emissions2010           5
# emissions2011           5
# emissions2012           5
# emissions2013           5
# emissions2014           5
# emissions2015           5
# emissions2016           5
# emissions2017           5
# emissions2018           5
# emissions2019           5
# emissions2020          19
# emissions2021          19
# emissions2022          19
# dtype: int64

# %%
notnull_data = data.dropna()

# %%
notnull_data
# Out:
#       State FIPS State  Tier 1 Code             Tier 1 Description Pollutant  \
# 5              1    AL            1         Fuel Comb. Elec. Util.  PM10-PRI
# 14             1    AL            2          Fuel Comb. Industrial  PM10-PRI
# 23             1    AL            3               Fuel Comb. Other  PM10-PRI
# 32             1    AL            4  Chemical & Allied Product Mfg  PM10-PRI
# 41             1    AL            5              Metals Processing  PM10-PRI
# ...          ...   ...          ...                            ...       ...
# 6784          56    WY            9            Storage & Transport  PM10-PRI
# 6793          56    WY           10     Waste Disposal & Recycling  PM10-PRI
# 6802          56    WY           11               Highway Vehicles  PM10-PRI
# 6811          56    WY           12                    Off-Highway  PM10-PRI
# 6820          56    WY           14                  Miscellaneous  PM10-PRI
#
# ...

# %%
years = ['emissions1996',	'emissions1997',	'emissions1998',	'emissions1999',	'emissions2000',	'emissions2001',	'emissions2002',	'emissions2003',	'emissions2004',	'emissions2005',	'emissions2006',	'emissions2007',	'emissions2008',	'emissions2009',	'emissions2010',	'emissions2011',	'emissions2012',	'emissions2013',	'emissions2014',	'emissions2015',	'emissions2016']

# %%
grouped_data = grouped_df = notnull_data.groupby('State')
# Out:
# State
# AK     146.33898
# AL     444.40523
# AR     396.97705
# AZ     278.15644
# CA    1058.73972
# CO     415.09908
# CT      58.09221
# DC       7.90616
# DE      27.01883
# FL     501.17018
# GA     722.29009
# HI      38.32277
# IA     569.81208
# ID     763.40298
# IL     922.48181
# IN     545.60373
# KS     868.90799
# KY     282.07340
# LA     332.69204
# MA     216.08893
# MD     141.09294
# ME      62.89922
# MI     433.72691
# MN     797.46291
# MO     977.29248
# MS     365.65799
# MT     460.34837
# NC     357.39746
# ND     382.65338
# NE     551.47375
# NH      36.78081
# NJ     164.39837
# NM     809.03815
# NV     187.49288
# NY     478.63925
# OH     581.47444
# OK     825.01459
# OR     714.91386
# PA     429.00786
# RI      16.83710
# SC     270.72687
# SD     314.64209
# TN     323.03599
# TX    2602.38927
# UT     226.28400
# VA     284.87445
# VT      51.84668
# WA     304.21865
# WI     352.05495
# WV     140.18057
# WY     610.94773
# ...

# %%
grouped_df = notnull_data.groupby('State').agg({'emissions1996': 'sum', 'emissions1997': 'sum', 'emissions1998': 'sum', 'emissions1999': 'sum', 'emissions2000': 'sum', 'emissions2001': 'sum', 'emissions2002': 'sum', 'emissions2003': 'sum', 'emissions2004': 'sum', 'emissions2005': 'sum', 'emissions2006': 'sum', 'emissions2007': 'sum', 'emissions2008': 'sum', 'emissions2009': 'sum', 'emissions2010': 'sum', 'emissions2011': 'sum', 'emissions2012': 'sum', 'emissions2013': 'sum', 'emissions2014': 'sum', 'emissions2015': 'sum', 'emissions2016': 'sum'})
grouped_df
# Out:
#        emissions1996  emissions1997  emissions1998  emissions1999  \
# State
# AK         146.33898      294.90270      100.07019     264.376167
# AL         444.40523      446.58369      468.50257     571.955762
# AR         396.97705      421.14678      431.92692     461.522623
# AZ         278.15644      277.72631      284.47977     303.495752
# CA        1058.73972     1328.38776     1239.27128     937.607841
# CO         415.09908      408.25310      427.59030     300.530276
# CT          58.09221       60.73919       60.06510      63.424200
# DC           7.90616        8.67248        8.21039       9.442455
# DE          27.01883       27.62753       28.52456      29.457559
# FL         501.17018      493.10136      511.60796     801.865043
# GA         722.29009      804.39932      769.12518     873.290818
# HI          38.32277       38.26107       37.11388      42.488492
# IA         569.81208      560.01124      560.94442     562.798564
# ...

# %%
reshaped_df = grouped_df.reset_index().melt(id_vars='State', var_name='Year', value_name='Emissions')
reshaped_df['Year'] = reshaped_df['Year'].str.extract('(\d+)', expand=False).astype(int)
reshaped_df
# Out:
#      State  Year    Emissions
# 0       AK  1996   146.338980
# 1       AL  1996   444.405230
# 2       AR  1996   396.977050
# 3       AZ  1996   278.156440
# 4       CA  1996  1058.739720
# ...    ...   ...          ...
# 1066    VT  2016    53.391512
# 1067    WA  2016   231.808384
# 1068    WI  2016   199.741686
# 1069    WV  2016    77.501345
# 1070    WY  2016   426.780451
#
# [1071 rows x 3 columns]

# %%
state_mapping = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming'
}

# %%
reshaped_df['State'] = reshaped_df['State'].map(state_mapping)

# %%
reshaped_df['State'].unique()
# Out:
# array(['Alaska', 'Alabama', 'Arkansas', 'Arizona', 'California',
#        'Colorado', 'Connecticut', nan, 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Iowa', 'Idaho', 'Illinois', 'Indiana', 'Kansas',
#        'Kentucky', 'Louisiana', 'Massachusetts', 'Maryland', 'Maine',
#        'Michigan', 'Minnesota', 'Missouri', 'Mississippi', 'Montana',
#        'North Carolina', 'North Dakota', 'Nebraska', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'Nevada', 'New York', 'Ohio',
#        'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'Virginia', 'Vermont', 'Washington', 'Wisconsin', 'West Virginia',
#        'Wyoming'], dtype=object)

# %%
reshaped_df
# Out:
#               State  Year    Emissions
# 0            Alaska  1996   146.338980
# 1           Alabama  1996   444.405230
# 2          Arkansas  1996   396.977050
# 3           Arizona  1996   278.156440
# 4        California  1996  1058.739720
# ...             ...   ...          ...
# 1066        Vermont  2016    53.391512
# 1067     Washington  2016   231.808384
# 1068      Wisconsin  2016   199.741686
# 1069  West Virginia  2016    77.501345
# 1070        Wyoming  2016   426.780451
#
# [1071 rows x 3 columns]

# %%
reshaped_df.dropna()
# Out:
#               State  Year    Emissions
# 0            Alaska  1996   146.338980
# 1           Alabama  1996   444.405230
# 2          Arkansas  1996   396.977050
# 3           Arizona  1996   278.156440
# 4        California  1996  1058.739720
# ...             ...   ...          ...
# 1066        Vermont  2016    53.391512
# 1067     Washington  2016   231.808384
# 1068      Wisconsin  2016   199.741686
# 1069  West Virginia  2016    77.501345
# 1070        Wyoming  2016   426.780451
#
# [1050 rows x 3 columns]

# %%
reshaped_df.to_csv('emissions_pollution.csv', index=False)

# %%
mortality_data = pd.read_csv('/content/1999 to 2016 mortality rate.csv')
# Out:
# <ipython-input-36-1d241d2a1607>:1: DtypeWarning: Columns (12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   mortality_data = pd.read_csv('/content/1999 to 2016 mortality rate.csv')

# %%
mortality_data
# Out:
#                                        ICD Chapter ICD Chapter Code  Year  \
# 0        Certain infectious and parasitic diseases          A00-B99  1999
# 1        Certain infectious and parasitic diseases          A00-B99  1999
# 2        Certain infectious and parasitic diseases          A00-B99  1999
# 3        Certain infectious and parasitic diseases          A00-B99  1999
# 4        Certain infectious and parasitic diseases          A00-B99  1999
# ...                                            ...              ...   ...
# 419351  External causes of morbidity and mortality          V01-Y89  2016
# 419352  External causes of morbidity and mortality          V01-Y89  2016
# 419353  External causes of morbidity and mortality          V01-Y89  2016
# 419354  External causes of morbidity and mortality          V01-Y89  2016
# 419355  External causes of morbidity and mortality          V01-Y89  2016
#
#         Year Code    State  State Code    2013 Urbanization  \
# ...

# %%
merged_df = mortality_data.merge(reshaped_df, on=['State', 'Year'], how='outer')
merged_df.tail()
# Out:
#        ICD Chapter ICD Chapter Code  Year  Year Code State  State Code  \
# 419522         NaN              NaN  2012        NaN   NaN         NaN
# 419523         NaN              NaN  2013        NaN   NaN         NaN
# 419524         NaN              NaN  2014        NaN   NaN         NaN
# 419525         NaN              NaN  2015        NaN   NaN         NaN
# 419526         NaN              NaN  2016        NaN   NaN         NaN
#
#        2013 Urbanization  2013 Urbanization Code Gender Age Group  \
# 419522               NaN                     NaN    NaN       NaN
# 419523               NaN                     NaN    NaN       NaN
# 419524               NaN                     NaN    NaN       NaN
# 419525               NaN                     NaN    NaN       NaN
# 419526               NaN                     NaN    NaN       NaN
#
#        Age Group Code  Deaths Population Crude Rate  \
# 419522            NaN     NaN        NaN        NaN
# ...

# %%
merged_df.to_csv('mortality_and_pollution.csv', index=False)

# %%
df = pd.read_csv("mortality_and_pollution.csv")
# Out:
# /var/folders/wn/xmcbx3pn7pd9dlgs5nc38hp00000gn/T/ipykernel_5355/832829979.py:1: DtypeWarning: Columns (12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("mortality_and_pollution.csv")

# %%
df["State"].value_counts()
# Out:
# Texas                   16996
# California              15183
# Florida                 14353
# New York                13909
# Pennsylvania            13891
# Ohio                    13728
# Georgia                 13503
# Illinois                13408
# Michigan                13166
# North Carolina          13094
# Tennessee               12167
# Alabama                 11848
# Indiana                 11738
# Virginia                11632
# Missouri                11127
# Louisiana               10833
# Kentucky                10526
# Wisconsin               10401
# Washington               9958
# Minnesota                9597
# Oklahoma                 9367
# Colorado                 9104
# Oregon                   9062
# Arizona                  8803
# South Carolina           8579
# New Jersey               8385
# Massachusetts            8213
# Kansas                   7621
# Mississippi              7539
# Arkansas                 7478
# Maryland                 7334
# ...

# %%
df[df["State"] == "Alaska"]
# Out:
#                                        ICD Chapter ICD Chapter Code  Year  \
# 21006                                    Neoplasms          C00-D48  1999
# 21007                                    Neoplasms          C00-D48  1999
# 21008                                    Neoplasms          C00-D48  1999
# 21009                                    Neoplasms          C00-D48  1999
# 21010                                    Neoplasms          C00-D48  1999
# ...                                            ...              ...   ...
# 395588  External causes of morbidity and mortality          V01-Y89  2016
# 395589  External causes of morbidity and mortality          V01-Y89  2016
# 395590  External causes of morbidity and mortality          V01-Y89  2016
# 395591  External causes of morbidity and mortality          V01-Y89  2016
# 395592  External causes of morbidity and mortality          V01-Y89  2016
#
#         Year Code   State  State Code   2013 Urbanization  \
# ...

# %%
# source: https://developers.google.com/public-data/docs/canonical/states_csv
state_coordinates_df = pd.read_csv("state_coordinates.csv")
state_coordinates_df = state_coordinates_df.rename(columns={"state": "state_short"})

# %%
geo_df = pd.merge(df, state_coordinates_df, left_on="State", right_on="name")
geo_df.drop(columns="name", inplace=True)

# %%
geo_df.shape, df.shape
# Out:
# ((419356, 21), (419356, 18))

# %%
(geo_df["Year"] == geo_df["Year Code"]).all()
# Out:
# True

# %%
geo_df["Year"].unique()
# Out:
# array([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
geo_df
# Out:
#                                        ICD Chapter ICD Chapter Code  Year  \
# 0        Certain infectious and parasitic diseases          A00-B99  1999
# 1        Certain infectious and parasitic diseases          A00-B99  1999
# 2        Certain infectious and parasitic diseases          A00-B99  1999
# 3        Certain infectious and parasitic diseases          A00-B99  1999
# 4        Certain infectious and parasitic diseases          A00-B99  1999
# ...                                            ...              ...   ...
# 419351  External causes of morbidity and mortality          V01-Y89  2016
# 419352  External causes of morbidity and mortality          V01-Y89  2016
# 419353  External causes of morbidity and mortality          V01-Y89  2016
# 419354  External causes of morbidity and mortality          V01-Y89  2016
# 419355  External causes of morbidity and mortality          V01-Y89  2016
#
#         Year Code    State  State Code    2013 Urbanization  \
# ...

# %%
pd.to_numeric(geo_df["Population"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/playground2/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Not Applicable"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pd.to_numeric(geo_df["Population"])
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/playground2/lib/python3.11/site-packages/pandas/core/tools/numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
# ...

# %%
for item in geo_df["Population"].unique():
    try: 
        int(item)
    except:
        print(item)
# Out:
# Not Applicable

# %%
geo_df[geo_df["Population"] == "Not Applicable"]
# Out:
#                                               ICD Chapter ICD Chapter Code  \
# 12264          External causes of morbidity and mortality          V01-Y89
# 14053          External causes of morbidity and mortality          V01-Y89
# 14521   Symptoms, signs and abnormal clinical and labo...          R00-R99
# 14535          External causes of morbidity and mortality          V01-Y89
# 14560          External causes of morbidity and mortality          V01-Y89
# 15502          External causes of morbidity and mortality          V01-Y89
# 15527          External causes of morbidity and mortality          V01-Y89
# 16736   Symptoms, signs and abnormal clinical and labo...          R00-R99
# 16977   Symptoms, signs and abnormal clinical and labo...          R00-R99
# 17008          External causes of morbidity and mortality          V01-Y89
# 28900          External causes of morbidity and mortality          V01-Y89
# ...

# %%
geo_df_clean = geo_df[geo_df["Population"] != "Not Applicable"].copy()
geo_df_clean["Population"] = pd.to_numeric(geo_df_clean["Population"])

# %%
aggregated_deaths = geo_df_clean.groupby(["State", "Year"]).agg(
    {
        "Deaths": "sum",
        "Population": "sum",
        "Emissions": "first",
        "latitude": "first",
        "longitude": "first"
    })

# %%
(2016-1999+1) * 51
# Out:
# 918

# %%
aggregated_deaths["Deaths_per_10,000"] = (aggregated_deaths["Deaths"] / aggregated_deaths["Population"]) * 10000

# %%
aggregated_deaths.reset_index().to_csv("deaths_by_state.csv", index=False)

# %%
aggregated_deaths.loc["Massachusetts"]["Deaths"].plot(kind="line")
# Out:
# <Axes: xlabel='Year'>

# %%
mass = aggregated_deaths.loc["Massachusetts"]

# %%
mass
# Out:
#       Deaths  Population   Emissions   latitude  longitude  Deaths_per_10,000
# Year
# 1999   53984    31429280  277.669489  42.407211 -71.382437          17.176340
# 2000   54735    32779130  275.314762  42.407211 -71.382437          16.698125
# 2001   54745    32957640  239.362894  42.407211 -71.382437          16.610716
# 2002   54971    33815985   77.186136  42.407211 -71.382437          16.255922
# 2003   54409    34717520   74.509055  42.407211 -71.382437          15.671914
# 2004   52623    33789466   79.396162  42.407211 -71.382437          15.573789
# 2005   52101    34152074   76.151717  42.407211 -71.382437          15.255589
# 2006   51642    32537191   76.150464  42.407211 -71.382437          15.871684
# 2007   51183    33966555   73.776862  42.407211 -71.382437          15.068646
# 2008   51762    35174704   71.954353  42.407211 -71.382437          14.715689
# 2009   50533    35418592   72.057611  42.407211 -71.382437          14.267366
# ...

# %%
sns.regplot(data=mass, y="Deaths_per_10,000", x=mass.index)
# Out:
# <Axes: xlabel='Year', ylabel='Deaths_per_10,000'>

# %%
geo_df_clean
# Out:
#                                        ICD Chapter ICD Chapter Code  Year  \
# 0        Certain infectious and parasitic diseases          A00-B99  1999
# 1        Certain infectious and parasitic diseases          A00-B99  1999
# 2        Certain infectious and parasitic diseases          A00-B99  1999
# 3        Certain infectious and parasitic diseases          A00-B99  1999
# 4        Certain infectious and parasitic diseases          A00-B99  1999
# ...                                            ...              ...   ...
# 419351  External causes of morbidity and mortality          V01-Y89  2016
# 419352  External causes of morbidity and mortality          V01-Y89  2016
# 419353  External causes of morbidity and mortality          V01-Y89  2016
# 419354  External causes of morbidity and mortality          V01-Y89  2016
# 419355  External causes of morbidity and mortality          V01-Y89  2016
#
#         Year Code    State  State Code    2013 Urbanization  \
# ...

# %%
aggregated_deaths_by_gender = geo_df_clean.groupby(["State", "Gender", "Year"]).agg(
    {
        "Deaths": "sum",
        "Population": "sum",
        "Emissions": "first",
        "latitude": "first",
        "longitude": "first"
    })
aggregated_deaths_by_gender["Deaths_per_10,000"] = (aggregated_deaths_by_gender["Deaths"] / aggregated_deaths_by_gender["Population"]) * 10000

aggregated_deaths_by_gender.reset_index().to_csv("deaths_by_state_and_gender.csv", index=False)

# %%
aggregated_deaths_by_gender
# Out:
#                      Deaths  Population   Emissions   latitude   longitude  \
# State   Gender Year
# Alabama Female 1999   21244     8525930  571.955762  32.318231  -86.902298
#                2000   21451     8825780  502.351006  32.318231  -86.902298
#                2001   21801     8919783  469.019542  32.318231  -86.902298
#                2002   22087     9167374  250.547750  32.318231  -86.902298
#                2003   22653    10240355  243.633359  32.318231  -86.902298
# ...                     ...         ...         ...        ...         ...
# Wyoming Male   2012    1804      515573  453.733959  43.075968 -107.290284
#                2013    1881      531890  394.873205  43.075968 -107.290284
#                2014    1926      523904  391.200699  43.075968 -107.290284
#                2015    2004      604028  411.597207  43.075968 -107.290284
#                2016    1976      572464  426.780451  43.075968 -107.290284
#
#                      Deaths_per_10,000
# ...

# %%
total_usa = aggregated_deaths_by_gender.groupby(level="Year").agg(
    {
        "Deaths": "sum",
        "Population": "sum",
        "Emissions": "first",
        "latitude": "first",
        "longitude": "first"
    })
total_usa["Deaths_per_10,000"] = (total_usa["Deaths"] / total_usa["Population"]) * 10000

# %%
total_usa
# Out:
#        Deaths  Population   Emissions   latitude  longitude  Deaths_per_10,000
# Year
# 1999  2291360  1497856031  571.955762  32.318231 -86.902298          15.297598
# 2000  2303019  1532819074  502.351006  32.318231 -86.902298          15.024728
# 2001  2315767  1581783413  469.019542  32.318231 -86.902298          14.640228
# 2002  2343252  1593136111  250.547750  32.318231 -86.902298          14.708423
# 2003  2348335  1627014710  243.633359  32.318231 -86.902298          14.433397
# 2004  2298481  1630438559  259.008069  32.318231 -86.902298          14.097317
# 2005  2349950  1677148930  265.519857  32.318231 -86.902298          14.011576
# 2006  2328367  1699575608  252.373289  32.318231 -86.902298          13.699696
# 2007  2328024  1715411904  267.292647  32.318231 -86.902298          13.571224
# 2008  2376170  1736544800  247.701136  32.318231 -86.902298          13.683321
# 2009  2341379  1786333379  222.501357  32.318231 -86.902298          13.107178
# ...

# %%
sns.lineplot(total_usa, x="Year", y="Deaths").set(title='Deaths in USA')
# Out:
# [Text(0.5, 1.0, 'Deaths in USA')]

# %%
sns.lineplot(total_usa, x="Year", y="Deaths_per_10,000").set(title='Deaths per 10000 in USA')
# Out:
# [Text(0.5, 1.0, 'Deaths per 10000 in USA')]

# %%
total_usa_by_gender = aggregated_deaths_by_gender.groupby(level=["Gender", "Year"]).agg(
    {
        "Deaths": "sum",
        "Population": "sum",
        "Emissions": "first",
        "latitude": "first",
        "longitude": "first"
    })
total_usa_by_gender["Deaths_per_10,000"] = (total_usa_by_gender["Deaths"] / total_usa_by_gender["Population"]) * 10000

# %%
sns.lineplot(total_usa_by_gender, x="Year", y="Deaths", hue="Gender").set(title='Deaths in USA')
# Out:
# [Text(0.5, 1.0, 'Deaths in USA')]

# %%
sns.lineplot(total_usa_by_gender, x="Year", y="Deaths_per_10,000", hue="Gender").set(title='Deaths per 10000 in USA')
# Out:
# [Text(0.5, 1.0, 'Deaths per 10000 in USA')]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
aggregated_deaths_by_gender
# Out:
#                      Deaths  Population   Emissions   latitude   longitude  \
# State   Gender Year
# Alabama Female 1999   21244     8525930  571.955762  32.318231  -86.902298
#                2000   21451     8825780  502.351006  32.318231  -86.902298
#                2001   21801     8919783  469.019542  32.318231  -86.902298
#                2002   22087     9167374  250.547750  32.318231  -86.902298
#                2003   22653    10240355  243.633359  32.318231  -86.902298
# ...                     ...         ...         ...        ...         ...
# Wyoming Male   2012    1804      515573  453.733959  43.075968 -107.290284
#                2013    1881      531890  394.873205  43.075968 -107.290284
#                2014    1926      523904  391.200699  43.075968 -107.290284
#                2015    2004      604028  411.597207  43.075968 -107.290284
#                2016    1976      572464  426.780451  43.075968 -107.290284
#
#                      Deaths_per_10,000
# ...

# %%
# Model 1:
model_df = aggregated_deaths_by_gender[aggregated_deaths_by_gender["Emissions"].notna()]
model1 = LinearRegression()
X1 = model_df[["Emissions"]].copy()
y1 = model_df['Deaths_per_10,000']
model1.fit(X1, y1)
print('Model 1 Coefficients:', model1.coef_)
print('Model 1 Intercept:', model1.intercept_)
# Out:
# Model 1 Coefficients: [-0.00615875]
# Model 1 Intercept: 24.87388139446381

# %%
# Model 2:
model_df2 = model_df.reset_index("Gender").copy()
model_df2["Gender"] = pd.get_dummies(model_df2['Gender'], drop_first=True)
model2 = LinearRegression()
X2 = model_df2[["Emissions", "Gender"]].copy()
y2 = model_df2['Deaths_per_10,000']
model2.fit(X2, y2)
print('Model 2 Coefficients:', model2.coef_)
print('Model 2 Intercept:', model2.intercept_)
# Out:
# Model 2 Coefficients: [-0.00615875 -2.30114605]
# Model 2 Intercept: 26.024454421879266

# %%
####

# %%
model_df2
# Out:
#               Gender  Deaths  Population   Emissions   latitude   longitude  \
# State   Year
# Alabama 1999       0   21244     8525930  571.955762  32.318231  -86.902298
#         2000       0   21451     8825780  502.351006  32.318231  -86.902298
#         2001       0   21801     8919783  469.019542  32.318231  -86.902298
#         2002       0   22087     9167374  250.547750  32.318231  -86.902298
#         2003       0   22653    10240355  243.633359  32.318231  -86.902298
# ...              ...     ...         ...         ...        ...         ...
# Wyoming 2012       1    1804      515573  453.733959  43.075968 -107.290284
#         2013       1    1881      531890  394.873205  43.075968 -107.290284
#         2014       1    1926      523904  391.200699  43.075968 -107.290284
#         2015       1    2004      604028  411.597207  43.075968 -107.290284
#         2016       1    1976      572464  426.780451  43.075968 -107.290284
#
#               Deaths_per_10,000
# ...

# %%
X2
# Out:
#                Emissions  Gender
# State   Year
# Alabama 1999  571.955762       0
#         2000  502.351006       0
#         2001  469.019542       0
#         2002  250.547750       0
#         2003  243.633359       0
# ...                  ...     ...
# Wyoming 2012  453.733959       1
#         2013  394.873205       1
#         2014  391.200699       1
#         2015  411.597207       1
#         2016  426.780451       1
#
# [1800 rows x 2 columns]

# %%
years = model_df2.reset_index("Year")["Year"]
years_train = (years < 2016).values
X2_train = X2[years_train]
y2_train = y2[years_train]
X2_test = X2[~years_train]
y2_test = y2[~years_train]
model2.fit(X2_train, y2_train)
print('Model 2 Coefficients:', model2.coef_)
print('Model 2 Intercept:', model2.intercept_)



# Predicting the outcome
predictions = model2.predict(X2_test)

# Evaluating accuracy
mse = mean_squared_error(y2_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Model 2 Coefficients: [-0.00627211 -2.40596295]
# Model 2 Intercept: 26.253506590479642
# Mean Squared Error: 67.25523828931092
